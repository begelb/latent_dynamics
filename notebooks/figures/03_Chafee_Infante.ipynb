# %%
# !pip install git+https://github.com/begelb/latent_dynamics.git

# %% [markdown]
# # Section 5.3 — Chafee-Infante PDE with bistability

# %% [markdown]
# # Chafee–Infante PDE — latent Morse graph (paper §5.4)

# %%
from latentdynamics.replay import load_experiment

exp = load_experiment("chafee_infante_replay")
exp

# %% [markdown]
# ## Morse graph

# %%
exp.show_morse_graph()

# %% [markdown]
# ## Morse sets

# %%
exp.show_morse_sets()

# %% [markdown]
# ## Run provenance

# %%
exp.diagnostics()
# Out:
# {'experiment': 'chafee_infante_marcio',
#  'seed': None,
#  'train_file': 'train',
#  'dims': '64 -> 2',
#  'seed_dir': 'replay_sources/chafee_infante/marcio',
#  'mg_params': {'lower_bounds': '[-3.0, -2.0]',
#   'upper_bounds': '[3.0, 2.0]',
#   'subdiv_init': '10',
#   'subdiv_min': '14',
#   'subdiv_max': '28',
#   'subdiv_limit': '10000',
#   'bounds_epsilon_frac': '0.01',
#   'padding': 'False',
#   'box_map_backend': 'auto',
#   'compute_roa': 'False',
#   'roa_max_vertices': '50000000',
#   'collapse_roa_to_lca': 'True',
#   'bounds_source': 'config',
#   'duration_minutes': '0.1631'},
#  'metrics': {'minimal_morse_labels': [0, 1],
#   'minimal_morse_sets': {'0': {'n_boxes': 1,
#     'tau_bar': 0.009708523750305176,
#     'warning': 'system is not a DiscreteMap; skipped semiconjugacy error'},
#    '1': {'n_boxes': 1,
#     'tau_bar': 0.0049432143568992615,
#     'warning': 'system is not a DiscreteMap; skipped semiconjugacy error'}}}}
